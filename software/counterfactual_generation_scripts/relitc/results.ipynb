# %%
import json
import numpy as np

# %%
f = open('./results\generated_counterfactuals\OLID\counterfactuals_explain_wrt-predicted_next_token_strategy-confidence_direction-highest_first.json'.replace('\\', '/'))

# %%
# Using readlines()
lines = f.readlines()

jsons = []

# Strips the newline character
for line in lines:
    jsons.append(json.loads(line))

# %%
lab_0 = []

for j in jsons:
#     print(j['original_label'])
    if j['original_label'] == 1:
        lab_0.append(j)

# %%
jsons[12]
# Out:
# {'id': 'test_15565',
#  'text': '#constoo the place for fed up conservatives !!!',
#  'label': 0,
#  'original_label': 0,
#  'pred_label': 0,
#  'pred_proba': 0.10744085162878,
#  'mask_frac': 0.03125,
#  'success': True,
#  'counterfactuals': [{'masked_text': '[CLS] offensive : # constoo the place [MASK] fed up conservatives!!! [SEP]',
#    'edited_output_text': '# constoo the place fuck fed up conservatives!!!',
#    'pred_proba': 0.8598360419273376,
#    'pred_class': 1,
#    'success': True,
#    'mask_frac': 0.03125,
#    'fluency': 1.2886304089620175,
#    'sem_similarity': 0.9134504795074463,
#    'minimality': 0.09090909090909091,
#    'fluency_mice': 0.9853944872678491},
#   {'masked_text': '[CLS] offensive : # constoo the place [MASK] fed up conservatives!!! [SEP]',
#    'edited_output_text': '# constoo the place sucks fed up conservatives!!!',
#    'pred_proba': 0.8208617568016052,
#    'pred_class': 1,
#    'success': True,
#    'mask_frac': 0.03125,
# ...

# %%
lab_0[10]
# Out:
# {'id': 'test_60587',
#  'text': '@user how is she hiding her ugly personality. she is the worst.',
#  'label': 1,
#  'original_label': 1,
#  'pred_label': 1,
#  'pred_proba': 0.8712974786758421,
#  'mask_frac': 0.28125,
#  'success': True,
#  'counterfactuals': [{'masked_text': '[CLS] not offensive : @ user how is she hiding [MASK] [MASK] [MASK]. she is the [MASK]. [SEP]',
#    'edited_output_text': '@ user how is she hiding the good side. she is the best.',
#    'pred_proba': 0.03754037618637085,
#    'pred_class': 0,
#    'success': True,
#    'mask_frac': 0.28125,
#    'fluency': 1.1673249815119282,
#    'sem_similarity': 0.734442949295044,
#    'minimality': 0.42857142857142855,
#    'fluency_mice': 1.0239252018833225},
#   {'masked_text': '[CLS] not offensive : @ user how is she hiding [MASK] [MASK] [MASK]. she is the [MASK]. [SEP]',
#    'edited_output_text': '@ user how is she hiding in trump country. she is the victim.',
#    'pred_proba': 0.33036261796951294,
# ...
